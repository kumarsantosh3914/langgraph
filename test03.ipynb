# %%
from typing import Annotated
from typing_extensions import TypedDict
from langgraph.graph import StateGraph, START
from langgraph.graph.message import add_messages
from dotenv import load_dotenv
from IPython.display import Image, display
import gradio as gr
from langgraph.prebuilt import ToolNode, tools_condition
import requests
import os
from langchain.agents import Tool

from langchain_openai import ChatOpenAI
from langgraph.checkpoint.memory import MemorySaver

# %%
load_dotenv(override=True)
# Out:
# True

# %%
class State(TypedDict):
    
    messages: Annotated[list, add_messages]


graph_builder = StateGraph(State)

# %%
pushover_token = os.getenv("PUSHOVER_TOKEN")
pushover_user = os.getenv("PUSHOVER_USER")
pushover_url = "https://api.pushover.net/1/messages.json"

def push(text: str):
    """Send a push notification to the user"""
    requests.post(pushover_url, data = {"token": pushover_token, "user": pushover_user, "message": text})

tool_push = Tool(
        name="send_push_notification",
        func=push,
        description="useful for when you want to send a push notification"
    )

# %%
# Introducing nest_asyncio
# Python async code only allows for one "event loop" processing aynchronous events.
# The `nest_asyncio` library patches this, and is used for special situations, if you need to run a nested event loop.

import nest_asyncio
nest_asyncio.apply()

# %%
from langchain_community.agent_toolkits import PlayWrightBrowserToolkit
from langchain_community.tools.playwright.utils import create_async_playwright_browser

# If you get a NotImplementedError here or later, see the Heads Up at the top of the notebook

async_browser =  create_async_playwright_browser(headless=False)  # headful mode
toolkit = PlayWrightBrowserToolkit.from_browser(async_browser=async_browser)
tools = toolkit.get_tools()

# %%
for tool in tools:
    print(f"{tool.name}={tool}")
# Out:
# click_element=async_browser=<Browser type=<BrowserType name=chromium executable_path=C:\Users\lenovo\AppData\Local\ms-playwright\chromium-1181\chrome-win\chrome.exe> version=139.0.7258.5>
# navigate_browser=async_browser=<Browser type=<BrowserType name=chromium executable_path=C:\Users\lenovo\AppData\Local\ms-playwright\chromium-1181\chrome-win\chrome.exe> version=139.0.7258.5>
# previous_webpage=async_browser=<Browser type=<BrowserType name=chromium executable_path=C:\Users\lenovo\AppData\Local\ms-playwright\chromium-1181\chrome-win\chrome.exe> version=139.0.7258.5>
# extract_text=async_browser=<Browser type=<BrowserType name=chromium executable_path=C:\Users\lenovo\AppData\Local\ms-playwright\chromium-1181\chrome-win\chrome.exe> version=139.0.7258.5>
# extract_hyperlinks=async_browser=<Browser type=<BrowserType name=chromium executable_path=C:\Users\lenovo\AppData\Local\ms-playwright\chromium-1181\chrome-win\chrome.exe> version=139.0.7258.5>
# get_elements=async_browser=<Browser type=<BrowserType name=chromium executable_path=C:\Users\lenovo\AppData\Local\ms-playwright\chromium-1181\chrome-win\chrome.exe> version=139.0.7258.5>
# current_webpage=async_browser=<Browser type=<BrowserType name=chromium executable_path=C:\Users\lenovo\AppData\Local\ms-playwright\chromium-1181\chrome-win\chrome.exe> version=139.0.7258.5>

# %%
tool_dict = {tool.name:tool for tool in tools}

navigate_tool = tool_dict.get("navigate_browser")
extract_text_tool = tool_dict.get("extract_text")

    
await navigate_tool.arun({"url": "https://www.cnn.com"})
text = await extract_text_tool.arun({})

# %%
import textwrap
print(textwrap.fill(text))
# Out:
# Breaking News, Latest News and Videos | CNN CNN values your feedback
# 1. How relevant is this ad to you? 2. Did you encounter any technical
# issues? No Video player was slow to load content Video content never
# loaded Ad froze or did not finish loading Video content did not start
# after ad Audio on ad was too loud Other issues Ad never loaded Ad
# prevented/slowed the page from loading Content moved around while ad
# loaded Ad was repetitive to ads I've seen previously Other issues
# Cancel Submit Thank You! Your effort and contribution in providing
# this feedback is much
# appreciated. Close Ad Feedback Close icon US World Politics Business
# Health Entertainment Style Travel Sports Science Climate Weather
# Ukraine-Russia War Israel-Hamas War Games More US World Politics
# Business Health Entertainment Style Travel Sports Science Climate
# Weather Ukraine-Russia War Israel-Hamas War Games Watch Listen Live TV
# Subscribe Sign in My Account Settings Newsletters Topics you follow
# Sign out Your CNN account Sign in to your CNN account Sign in My
# Account Settings Newsletters Topics you follow Sign out Your CNN
# account Sign in to your CNN account Live TV Listen Watch Edition US
# International Arabic Español Edition US International Arabic Español
# World Africa Americas Asia Australia China Europe India Middle East
# United Kingdom US Politics Trump Facts First CNN Polls 2025 Elections
# Business Tech Media Calculators Videos Markets Pre-markets After-Hours
# Fear & Greed Investing Markets Now Nightcap Health Life, But Better
# Fitness Food Sleep Mindfulness Relationships Entertainment Movies
# Television Celebrity Tech Innovate Foreseeable Future Mission: Ahead
# Work Transformed Innovative Cities Style Arts Design Fashion
# Architecture Luxury Beauty Video Travel Destinations Food & Drink Stay
# News Videos Sports Football Tennis Golf Motorsport US Sports Olympics
# Climbing Esports Hockey Science Space Life Unearthed Climate Solutions
# Weather Weather Video Climate Ukraine-Russia War Israel-Hamas War
# Features As Equals Call to Earth Freedom Project Impact Your World
# Inside Africa CNN Heroes Watch Live TV CNN Fast Shows A-Z CNN10 CNN
# Max CNN TV Schedules Listen CNN 5 Things Chasing Life with Dr. Sanjay
# Gupta The Assignment with Audie Cornish One Thing Tug of War CNN
# Political Briefing The Axe Files All There Is with Anderson Cooper All
# CNN Audio podcasts Games Daily Crossword Jumble Crossword Photo
# Shuffle Sudoblock Sudoku 5 Things Quiz About CNN Photos Investigations
# CNN Profiles CNN Leadership CNN Newsletters Work for CNN Follow CNN
# info The top numbered articles will be viewable to readers when
# programmed onto a page. Make sure you have 30 or more cards added to
# the container for the machine learning (ML) feature to work. Your
# queued up articles, seen in the violet section, will use ML to surface
# up relevant content to the reader based on their individual interests
# and preferences. Anas Al-Sharif Trump’s DC crackdown Musk threatens to
# sue Apple Trump’s major China gamble Jellyfish at nuclear plant
# Ronaldo-Rodríguez engagement info The top numbered articles will be
# viewable to readers when programmed onto a page. Make sure you have 30
# or more cards added to the container for the machine learning (ML)
# feature to work. Your queued up articles, seen in the violet section,
# will use ML to surface up relevant content to the reader based on
# their individual interests and preferences. Pierre Crom/Getty Images
# Panic in eastern Ukraine as Trump entertains idea of giving parts of
# it to Russia Across the Donetsk region, word of Steve Witkoff’s
# emerging deal with the Kremlin, confused in details, and immediately
# refused by Kyiv, has put lives already ravaged by war into a deeper
# spin. • Video 4:54 Clipped From Video Video The Ukrainians that risk
# being swapped to Russia 4:54 As Trump floats the idea of ceding
# Ukrainian territory with Russia, CNN’s Chief International Security
# Correspondent Nick Paton Walsh meets Ukrainians in the city that could
# become Moscow territory. info The top numbered articles will be
# viewable to readers when programmed onto a page. Make sure you have 30
# or more cards added to the container for the machine learning (ML)
# feature to work. Your queued up articles, seen in the violet section,
# will use ML to surface up relevant content to the reader based on
# their individual interests and preferences. AFP/Getty Images Anas Al-
# Sharif became the face of the war in Gaza for millions. Then Israel
# killed him As a ceasefire in Gaza took hold in January, Anas Al-Sharif
# began removing his protective gear live on television, piece by piece,
# while a jubilant crowd cheered, hoping the day marked the end of the
# suffering of 2 million Palestinians in the enclave. Dimitrios
# Kambouris/Getty Images/File Madonna asks Pope Leo to visit Gaza
# Madonna has urged Pope Leo to visit Gaza in a humanitarian mission to
# help starving Palestinian children, saying “there is no more time.”
# CNN Here are the countries that have recognized a Palestinian state A
# growing number of countries are pledging to recognize a Palestinian
# state, with more than 145 nations now joining the call for
# international recognition. info The top numbered articles will be
# viewable to readers when programmed onto a page. Make sure you have 30
# or more cards added to the container for the machine learning (ML)
# feature to work. Your queued up articles, seen in the violet section,
# will use ML to surface up relevant content to the reader based on
# their individual interests and preferences. Here's how Trump is able
# to deploy the National Guard to DC Show all Ken Cedeno/Reuters The
# president’s move came after the assault of a former DOGE worker during
# an attempted carjacking • Analysis Analysis Analysis Trump’s DC
# crackdown could take a much darker turn Trump has federalized DC’s
# police force. Now what? • Video 0:42 Video Statistics show DC’s
# violent crime rate has been declining 0:42 President Donald Trump
# cited pervasive crime as justification for federalizing police in the
# nation’s capital, but statistics for crime in Washington, DC tell a
# different story in recent years. info The top numbered articles will
# be viewable to readers when programmed onto a page. Make sure you have
# 30 or more cards added to the container for the machine learning (ML)
# feature to work. Your queued up articles, seen in the violet section,
# will use ML to surface up relevant content to the reader based on
# their individual interests and preferences. Play Catch up on today's
# global news - Source: CNN Video Catch up on today’s global news info
# The top numbered articles will be viewable to readers when programmed
# onto a page. Make sure you have 30 or more cards added to the
# container for the machine learning (ML) feature to work. Your queued
# up articles, seen in the violet section, will use ML to surface up
# relevant content to the reader based on their individual interests and
# preferences. DPPA/Sipa Cristiano Ronaldo and Georgina Rodríguez
# announce their engagement Kevin Winter/Getty Images/TAS Rights Mana
# Taylor Swift announces new album, ‘The Life of a Showgirl’ • Video
# 2:12 CNN Video LA shelters see increase in pets surrendered due to
# immigration raids 2:12 Ad Feedback info The top numbered articles will
# be viewable to readers when programmed onto a page. Make sure you have
# 30 or more cards added to the container for the machine learning (ML)
# feature to work. Your queued up articles, seen in the violet section,
# will use ML to surface up relevant content to the reader based on
# their individual interests and preferences. More top stories •
# Analysis Analysis Philippine Coast Guard Analysis Chinese ‘overkill’
# in dispute with Philippines damaged two Chinese ships. Why it could
# have been much worse Video Chinese ships collide in South China Sea
# 0:31 Shohei Ohtani and agent accused of sabotaging $240M Hawaii real
# estate project Analysis Trump’s major China gamble has paid off so
# far. But Xi still holds trump cards Elon Musk threatens to sue Apple
# over app store ranking of his AI app Trump ushers in an era of
# ‘shakedown’ capitalism info The top numbered articles will be viewable
# to readers when programmed onto a page. Make sure you have 30 or more
# cards added to the container for the machine learning (ML) feature to
# work. Your queued up articles, seen in the violet section, will use ML
# to surface up relevant content to the reader based on their individual
# interests and preferences. SCIENCE & DISCOVERY Institute of Deep-sea
# Science and Engineering/Chinese Academy of Sciences (IDSSE, CAS)
# Scientists discover ecosystem nearly 30,000 feet under the sea where
# ‘life needs tricks to survive’ info The top numbered articles will be
# viewable to readers when programmed onto a page. Make sure you have 30
# or more cards added to the container for the machine learning (ML)
# feature to work. Your queued up articles, seen in the violet section,
# will use ML to surface up relevant content to the reader based on
# their individual interests and preferences. British Antarctic
# Survey/PA/Alamy/Sipa Melting ice reveals remains of Antarctic
# researcher who vanished 66 years ago Aug 12, 2025 TravelCouples/Moment
# RF/Getty Images/File Live longer by walking faster, experts say Aug
# 11, 2025 Ad Feedback info The top numbered articles will be viewable
# to readers when programmed onto a page. Make sure you have 30 or more
# cards added to the container for the machine learning (ML) feature to
# work. Your queued up articles, seen in the violet section, will use ML
# to surface up relevant content to the reader based on their individual
# interests and preferences. Epstein files Photo Illustration by Alberto
# Mier/CNN/Getty Images Donald Trump and Jeffrey Epstein’s relationship:
# A visual timeline Aug 12, 2025 Davidoff Studios Photography/Archive
# Photos/Getty Images Analysis A judge’s brutal rebuke of Trump’s
# Epstein gambit Aug 11, 2025 US District Court for the Southern
# District of New York Federal judge rejects Trump DOJ’s bid to unseal
# grand jury materials in Maxwell case Aug 11, 2025 Ad Feedback info The
# top numbered articles will be viewable to readers when programmed onto
# a page. Make sure you have 30 or more cards added to the container for
# the machine learning (ML) feature to work. Your queued up articles,
# seen in the violet section, will use ML to surface up relevant content
# to the reader based on their individual interests and preferences.
# Travel & beyond • Video 1:57 CNN • Video 1:57 Video The restaurant
# where 'table for two' takes on an entirely different meaning 1:57 info
# The top numbered articles will be viewable to readers when programmed
# onto a page. Make sure you have 30 or more cards added to the
# container for the machine learning (ML) feature to work. Your queued
# up articles, seen in the violet section, will use ML to surface up
# relevant content to the reader based on their individual interests and
# preferences. Daniel Slim/AFP/Getty Images Spirit Airlines raises
# doubts about its ability to stay in business, months after exiting
# bankruptcy Catherine Phillips/CNN Why Tokyo’s official souvenir has
# nothing to do with Tokyo Ad Feedback info The top numbered articles
# will be viewable to readers when programmed onto a page. Make sure you
# have 30 or more cards added to the container for the machine learning
# (ML) feature to work. Your queued up articles, seen in the violet
# section, will use ML to surface up relevant content to the reader
# based on their individual interests and preferences. Military Show all
# Australian Department of Defence Implications of Japan selling
# advanced warships to another key US ally TV Zvezda Russia built a
# massive drone factory to pump out Iranian-designed drones. Now it’s
# leaving Tehran out in the cold Agencja Gazeta/Reuters What are Patriot
# missiles and why does Ukraine need them so badly? info The top
# numbered articles will be viewable to readers when programmed onto a
# page. Make sure you have 30 or more cards added to the container for
# the machine learning (ML) feature to work. Your queued up articles,
# seen in the violet section, will use ML to surface up relevant content
# to the reader based on their individual interests and preferences.
# Trump’s tariffs STR/AFP/Getty Images US and China agree to critical
# extension, preventing tariff surge on the world’s two largest
# economies Timur Matahari/AFP/Getty Images Trump wanted manufacturers
# to diversify away from China. Now many face stiff new tariffs Josh
# Edelson/AFP/Getty Images How the world’s most valuable company got
# caught in the middle of Trump’s spat with China Ad Feedback info The
# top numbered articles will be viewable to readers when programmed onto
# a page. Make sure you have 30 or more cards added to the container for
# the machine learning (ML) feature to work. Your queued up articles,
# seen in the violet section, will use ML to surface up relevant content
# to the reader based on their individual interests and preferences.
# Extraordinary People Show all US military/Courtesy of Nagasaki Atomic
# Bomb Museum How the atomic bombing of Nagasaki tore apart Japan’s
# understanding of motherhood Jen Pawol makes baseball history as first
# woman to umpire an MLB game info The top numbered articles will be
# viewable to readers when programmed onto a page. Make sure you have 30
# or more cards added to the container for the machine learning (ML)
# feature to work. Your queued up articles, seen in the violet section,
# will use ML to surface up relevant content to the reader based on
# their individual interests and preferences. Sports Richard A.
# Brooks/AFP/Getty Images Ski jumping’s suit-cheating saga rolls on as 5
# Norwegians are charged over ‘manipulation’ Power outage disrupts
# Cincinnati Open info The top numbered articles will be viewable to
# readers when programmed onto a page. Make sure you have 30 or more
# cards added to the container for the machine learning (ML) feature to
# work. Your queued up articles, seen in the violet section, will use ML
# to surface up relevant content to the reader based on their individual
# interests and preferences. Business & Technology Show all Fredrik
# Solstad/Bloomberg/Getty Images World’s biggest investment fund expects
# to sell more Israeli stocks due to situation in Gaza and West Bank How
# AI is being used in police stations to help draft reports Ad Feedback
# info The top numbered articles will be viewable to readers when
# programmed onto a page. Make sure you have 30 or more cards added to
# the container for the machine learning (ML) feature to work. Your
# queued up articles, seen in the violet section, will use ML to surface
# up relevant content to the reader based on their individual interests
# and preferences. Celebrities & Entertainment Kevin Mazur/Getty Images
# for Live Nation Demi Lovato reunites with ex-boyfriend Joe Jonas for a
# ‘Camp Rock’ performance Video Rick Ross has one of the largest
# backyard pools in the US. And he knows how to use it 2:40 info The top
# numbered articles will be viewable to readers when programmed onto a
# page. Make sure you have 30 or more cards added to the container for
# the machine learning (ML) feature to work. Your queued up articles,
# seen in the violet section, will use ML to surface up relevant content
# to the reader based on their individual interests and preferences.
# Climate & Extreme weather CIRA/RAMMB/NOAA Tropical Storm Erin forms in
# the Atlantic and is expected to strengthen into the first hurricane of
# the season Colorado prison evacuated as growing wildfire becomes one
# of the largest in state history info The top numbered articles will be
# viewable to readers when programmed onto a page. Make sure you have 30
# or more cards added to the container for the machine learning (ML)
# feature to work. Your queued up articles, seen in the violet section,
# will use ML to surface up relevant content to the reader based on
# their individual interests and preferences. Art & Style Show all Larry
# Sultan/Courtesy Yancey Richardson Gallery/Casemore Gallery/Estate of
# Larry Sultan The unassuming suburban homes that hosted and inspired
# porn sets How this designer became the go-to for unconventional brides
# info The top numbered articles will be viewable to readers when
# programmed onto a page. Make sure you have 30 or more cards added to
# the container for the machine learning (ML) feature to work. Your
# queued up articles, seen in the violet section, will use ML to surface
# up relevant content to the reader based on their individual interests
# and preferences. Call to Earth Show all Mark Ian Cook/Mangrove
# Photography Awards Bright pink birds, a snacking monkey and lurking
# crocodiles among winners of photo prize Adam Knox/American Bird
# Conservancy Thousands of mosquitoes are being dropped by drone over
# islands in Hawaii. Here’s why Christian Åslund /Norwegian Polar
# Institute /Greenpeace Before and after photos show Arctic glaciers’
# dramatic retreat Tom Booth/CNN ‘Super corals’ and supplements: Inside
# the lab trying to save the Great Barrier Reef Ad Feedback More from
# CNN info The top numbered articles will be viewable to readers when
# programmed onto a page. Make sure you have 30 or more cards added to
# the container for the machine learning (ML) feature to work. Your
# queued up articles, seen in the violet section, will use ML to surface
# up relevant content to the reader based on their individual interests
# and preferences. CNN Rick Ross has one of the largest pools in the US.
# Life is going swimmingly for the hip-hop star info The top numbered
# articles will be viewable to readers when programmed onto a page. Make
# sure you have 30 or more cards added to the container for the machine
# learning (ML) feature to work. Your queued up articles, seen in the
# violet section, will use ML to surface up relevant content to the
# reader based on their individual interests and preferences. ‘The
# courts are helpless’: Inside the Trump administration’s steady erosion
# of judicial power Pam Bondi has a new probe into the handling of 2016
# Russian meddling despite prior four-year investigation Private Welsh
# island with 19th century fort goes on the market The legal battle over
# Trump’s use of the National Guard moves to a California courtroom
# IndyCar officials and Pato O’Ward shocked by ICE-related ‘Speedway
# Slammer’ post Two Chinese nationals in US accused of illegally
# shipping Nvidia AI chips to China Astronaut retires after spending 9
# unexpected months in space Inside the home of Pauline Karpidas, the
# art-world ‘grande dame’ who could be the last of her kind Subscribe
# Sign in My Account Settings Newsletters Topics you follow Sign out
# Your CNN account Sign in to your CNN account Live TV Listen Watch
# World Africa Americas Asia Australia China Europe India Middle East
# United Kingdom US Politics Trump Facts First CNN Polls 2025 Elections
# Business Tech Media Calculators Videos Markets Pre-markets After-Hours
# Fear & Greed Investing Markets Now Nightcap Health Life, But Better
# Fitness Food Sleep Mindfulness Relationships Entertainment Movies
# Television Celebrity Tech Innovate Foreseeable Future Mission: Ahead
# Work Transformed Innovative Cities Style Arts Design Fashion
# Architecture Luxury Beauty Video Travel Destinations Food & Drink Stay
# News Videos Sports Football Tennis Golf Motorsport US Sports Olympics
# Climbing Esports Hockey Science Space Life Unearthed Climate Solutions
# Weather Weather Video Climate Ukraine-Russia War Israel-Hamas War
# Features As Equals Call to Earth Freedom Project Impact Your World
# Inside Africa CNN Heroes Watch Live TV CNN Fast Shows A-Z CNN10 CNN
# Max CNN TV Schedules Listen CNN 5 Things Chasing Life with Dr. Sanjay
# Gupta The Assignment with Audie Cornish One Thing Tug of War CNN
# Political Briefing The Axe Files All There Is with Anderson Cooper All
# CNN Audio podcasts Games Daily Crossword Jumble Crossword Photo
# Shuffle Sudoblock Sudoku 5 Things Quiz About CNN Photos Investigations
# CNN Profiles CNN Leadership CNN Newsletters Work for CNN Watch Listen
# Live TV Follow CNN Subscribe Sign in My Account Settings Newsletters
# Topics you follow Sign out Your CNN account Sign in to your CNN
# account Terms of Use Privacy Policy Manage Cookies Ad Choices
# Accessibility & CC About Newsletters Transcripts © 2025 Cable News
# Network. A Warner Bros. Discovery Company. All Rights Reserved. CNN
# Sans ™ & © 2016 Cable News Network. Privacy Policy For privacy
# options, please see our privacy policy: https://www.cnn.com/privacy .
# Back Button Cookie List Search Icon Filter Icon Clear checkbox label
# label Apply Cancel Consent Leg.Interest checkbox label label checkbox
# label label checkbox label label Close

# %%
all_tools = tools + [tool_push]

# %%
llm = ChatOpenAI(model="gpt-4o-mini")
llm_with_tools = llm.bind_tools(all_tools)


def chatbot(state: State):
    return {"messages": [llm_with_tools.invoke(state["messages"])]}

# %%
graph_builder = StateGraph(State)
graph_builder.add_node("chatbot", chatbot)
graph_builder.add_node("tools", ToolNode(tools=all_tools))
graph_builder.add_conditional_edges( "chatbot", tools_condition, "tools")
graph_builder.add_edge("tools", "chatbot")
graph_builder.add_edge(START, "chatbot")

memory = MemorySaver()
graph = graph_builder.compile(checkpointer=memory)
display(Image(graph.get_graph().draw_mermaid_png()))

# %%
config = {"configurable": {"thread_id": "10"}}

async def chat(user_input: str, history):
    result = await graph.ainvoke({"messages": [{"role": "user", "content": user_input}]}, config=config)
    return result["messages"][-1].content


gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
